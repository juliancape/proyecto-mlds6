# %% [markdown]
# # Reporte Modelo Baseline

# %% [markdown]
# ### Descripción del modelo

# %% [markdown]
# El modelo XGBClassifier es un clasificador de gradient boosting basado en el algoritmo XGBoost (Extreme Gradient Boosting). Es un tipo de modelo de aprendizaje automático que se utiliza para problemas de clasificación.

# %% [markdown]
# ### Variables de entrada

# %% [markdown]
# | Nombre | Descripción | Tipo de atributo |Tipo de dato  |rango de valores o numero de categorias|
#  | :--- | :--- | :--- | :--- | :--- |
#  |gender|genero de la persona|propio del sujeto|categorico  object|string 3 categorias|
#  |age| edad de la persona |propio del sujeto|numerico float64| rango [0.08, 80.0]|
#  |hypertension|persona sufre de hipertension|propio del sujeto|numerico int64| rango [0, 1] |
#  |heart_disease|persona padece de enfermedades del corazon| propio del sujeto| numerico int64| rango [0, 1]  |
#  |smoking_history| persona fumadora| propio del sujeto| categorico object|string 6 categorias |
#  |bmi|porcentaje de grasa corporal|propio del sujeto|numerico float64| rango [10.01, 95.69] |
#  |HbA1c_level|nivel de hemoglobina glicosilada|propio del sujeto|numerico float64| rango [3.5, 9.0] |
#  |blood_glucose_level|nivel de glucosa en la sangre de la persona|propio del sujeto|numerico int64| rango [80, 300] |

# %% [markdown]
# ### Variable objetivo

# %% [markdown]
# | Nombre | Descripción | Tipo de atributo |Tipo de dato  |rango de valores o numero de categorias|
#  | :--- | :--- | :--- | :--- | :--- |
#  |diabetes|persona padece de diabetes|propio del sujeto| numerico int64| rango [0, 1]|

# %% [markdown]
# ### Evaluación del modelo y Análisis de los resultados

# %%
print("Model validation accuracy: %.2f%%" % (grid_search.score(X_test, y_test) * 100))
# Out:
# Model validation accuracy: 97.39%

# %% [markdown]
# La precisión es una medida importante para evaluar el rendimiento de un modelo, pero es esencial tener en cuenta que no proporciona una imagen completa del rendimiento. Un modelo con una precisión del 97.39% en la validación indica que está realizando una clasificación muy precisa en los datos utilizados para la evaluación

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Etiqueta Predicha')
plt.ylabel('Etiqueta Real')
plt.show()

# %% [markdown]
# - Verdaderos positivos (True Positives, TP): 18283
# Estos son los casos en los que el modelo predijo correctamente que una persona tenía diabetes y, de hecho, esa persona tenía diabetes.
#
# - Falsos negativos (False Negatives, FN): 13
# Estos son los casos en los que el modelo predijo incorrectamente que una persona no tenía diabetes, pero en realidad, esa persona tenía diabetes.
#
# - Falsos positivos (False Positives, FP): 508
# Estos son los casos en los que el modelo predijo incorrectamente que una persona tenía diabetes, pero en realidad, esa persona no tenía diabetes.
#
# - Verdaderos negativos (True Negatives, TN): 1196
# Estos son los casos en los que el modelo predijo correctamente que una persona no tenía diabetes y, de hecho, esa persona no tenía diabetes.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Basándonos en la precisión del modelo del 97.39% y la matriz de confusión proporcionada, se puede llegar a la siguiente conclusión:
#
# El modelo muestra un alto rendimiento en la clasificación de muestras, con una precisión del 97.39%. Esto significa que el modelo logró clasificar correctamente la gran mayoría de las muestras en el conjunto de validación. Sin embargo, al observar la matriz de confusión, se puede notar que hubo algunos casos en los que el modelo cometió errores.
#
# Específicamente, se observa un bajo número de falsos negativos (13) y falsos positivos (508), lo que indica que el modelo cometió relativamente pocos errores al clasificar las muestras como negativas o positivas respectivamente. Esto es positivo, ya que minimizar los falsos negativos es especialmente importante en problemas de diagnóstico médico, como la detección de enfermedades.
#
# Por otro lado, los verdaderos positivos (18283) y verdaderos negativos (1196) tienen valores significativamente más altos, lo cual es alentador. Los verdaderos positivos representan los casos en los que el modelo acertó al predecir la presencia de diabetes, y los verdaderos negativos representan los casos en los que el modelo acertó al predecir la ausencia de diabetes.
#
# En general, el modelo muestra un desempeño sólido en la clasificación de las muestras en términos de precisión. Sin embargo, es importante considerar otras métricas y realizar una evaluación más exhaustiva según los requisitos y objetivos específicos del problema. También se recomienda analizar más detalladamente los casos de falsos negativos y falsos positivos para entender las posibles áreas de mejora del modelo.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3811282c-63b6-4ca2-ab7f-f472b62191a1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
