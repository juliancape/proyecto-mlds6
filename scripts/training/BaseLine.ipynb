# %% [markdown]
# # Training

# %%
import pandas as pd
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv('/work/diabetes_prediction_dataset.csv')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
cat_cols = ["gender", "smoking_history"]
enc = OrdinalEncoder()

df[cat_cols] = enc.fit_transform(df[cat_cols])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0     0.0  80.0             0              1              4.0  25.19
# 1     0.0  54.0             0              0              0.0  27.32
# 2     1.0  28.0             0              0              4.0  27.32
# 3     0.0  36.0             0              0              1.0  23.45
# 4     1.0  76.0             1              1              1.0  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop("diabetes", axis=1), df["diabetes"], test_size=0.2, random_state=6)

# %% [markdown]
# Model architechure

# %%
model = XGBClassifier(
    n_estimators=400,
    max_depth=3,
    learning_rate=0.1,
)

# %% [markdown]
# Model training

# %%
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric="error",
    early_stopping_rounds=500,
    verbose=10,
)
# Out:
# [0]	validation_0-error:0.02670
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [10]	validation_0-error:0.02670
# [20]	validation_0-error:0.02670
# [30]	validation_0-error:0.02670
# [40]	validation_0-error:0.02670
# [50]	validation_0-error:0.02670
# [60]	validation_0-error:0.02670
# [70]	validation_0-error:0.02670
# [80]	validation_0-error:0.02670
# [90]	validation_0-error:0.02665
# [100]	validation_0-error:0.02670
# [110]	validation_0-error:0.02665
# [120]	validation_0-error:0.02640
# [130]	validation_0-error:0.02640
# [140]	validation_0-error:0.02645
# [150]	validation_0-error:0.02640
# [160]	validation_0-error:0.02635
# [170]	validation_0-error:0.02615
# [180]	validation_0-error:0.02615
# [190]	validation_0-error:0.02630
# [200]	validation_0-error:0.02605
# [210]	validation_0-error:0.02605
# [220]	validation_0-error:0.02605
# [230]	validation_0-error:0.02610
# [240]	validation_0-error:0.02615
# [250]	validation_0-error:0.02640
# [260]	validation_0-error:0.02640
# [270]	validation_0-error:0.02640
# [280]	validation_0-error:0.02645
# [290]	validation_0-error:0.02640
# [300]	validation_0-error:0.02645
# [310]	validation_0-error:0.02650
# [320]	validation_0-error:0.02640
# [330]	validation_0-error:0.02650
# [340]	validation_0-error:0.02635
# [350]	validation_0-error:0.02635
# [360]	validation_0-error:0.02630
# [370]	validation_0-error:0.02640
# [380]	validation_0-error:0.02635
# [390]	validation_0-error:0.02645
# [399]	validation_0-error:0.02645
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=400, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# Model evaluation

# %%
print("Model validation accuracy: %.2f%%" % (model.score(X_test, y_test) * 100))
# Out:
# Model validation accuracy: 97.39%

# %%
xgb.plot_importance(model)
plt.show()

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
cm
# Out:
# array([[18283,    13],
#        [  508,  1196]])

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Etiqueta Predicha')
plt.ylabel('Etiqueta Real')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3811282c-63b6-4ca2-ab7f-f472b62191a1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
